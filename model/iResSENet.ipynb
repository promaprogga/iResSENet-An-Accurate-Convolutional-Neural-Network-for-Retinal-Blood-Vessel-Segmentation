# %% [markdown]
# <a href="https://colab.research.google.com/github/promaprogga/iResSENet-An-Accurate-Convolutional-Neural-Network-for-Retinal-Blood-Vessel-Segmentation/blob/main/model/iResSENet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import *
from keras.backend import int_shape
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Add, BatchNormalization,  Activation, MaxPool2D 
from tensorflow.keras.layers import Conv2DTranspose, Concatenate, Input, GlobalAveragePooling2D, Reshape, Dense, multiply

# Convolutional block
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("gelu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("gelu")(x)

    return x

# Squeeze and excitation block  
def se_block(block_input, num_filters, ratio=8):                            

	pool1 = GlobalAveragePooling2D()(block_input)
	flat = Reshape((1, 1, num_filters))(pool1)
	dense1 = Dense(num_filters//ratio, activation='gelu')(flat)
	dense2 = Dense(num_filters, activation='sigmoid')(dense1)
	scale = multiply([block_input, dense2])
	
	return scale


# Single ResNet block
def resnet_block(block_input, num_filters):                                  


	if int_shape(block_input)[3] != num_filters:
		block_input = Conv2D(num_filters, kernel_size=(1, 1))(block_input)
	
	conv1 = Conv2D(num_filters, kernel_size=(1, 1), padding='same')(block_input)
	norm1 = BatchNormalization()(conv1)
	relu1 = Activation('gelu')(norm1)
	conv2 = Conv2D(num_filters, kernel_size=(3,3), padding='same')(relu1)
	norm2 = BatchNormalization()(conv2)
	
	se = se_block(norm2, num_filters=num_filters)
	
	sum = Add()([block_input, se])
	relu2 = Activation('gelu')(sum)
	
	return relu2



# Single Encoder block
def encoder_block(inputs, num_filters, length):
    x = resnet_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
  
    return x, p


# Single Decoder block
def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# iResSENet
def build_iResSENet(input_shape):
    inputs = Input(input_shape)

    p0 = inputs
    s1, p1 = encoder_block(p0, 32, 4)
    s2, p2 = encoder_block(p1, 64, 3)
    s3, p3 = encoder_block(p2, 128, 2)
    s4, p4 = encoder_block(p3, 256, 1)

    b1 = conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="iResSENet")
    return model


input_shape = (512, 512, 3)
model = build_iResSENet(input_shape)
model.summary()
# Out:
# Model: "iResSENet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_95 (Conv2D)             (None, 512, 512, 32  128         ['input_6[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 512, 512, 32  1056        ['conv2d_95[0][0]']
#                                 )
#
#  batch_normalization_74 (BatchN  (None, 512, 512, 32  128        ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  activation_73 (Activation)     (None, 512, 512, 32  0           ['batch_normalization_74[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 512, 512, 32  9248        ['activation_73[0][0]']
#                                 )
#
#  batch_normalization_75 (BatchN  (None, 512, 512, 32  128        ['conv2d_97[0][0]']
#  ormalization)                  )
#
#  global_average_pooling2d_17 (G  (None, 32)          0           ['batch_normalization_75[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_17 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_17[0][
#                                                                  0]']
#
#  dense_34 (Dense)               (None, 1, 1, 4)      132         ['reshape_17[0][0]']
#
#  dense_35 (Dense)               (None, 1, 1, 32)     160         ['dense_34[0][0]']
#
#  multiply_16 (Multiply)         (None, 512, 512, 32  0           ['batch_normalization_75[0][0]',
#                                 )                                 'dense_35[0][0]']
#
#  add_16 (Add)                   (None, 512, 512, 32  0           ['conv2d_95[0][0]',
#                                 )                                 'multiply_16[0][0]']
#
#  activation_74 (Activation)     (None, 512, 512, 32  0           ['add_16[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 256, 256, 32  0          ['activation_74[0][0]']
#  )                              )
#
#  conv2d_98 (Conv2D)             (None, 256, 256, 64  2112        ['max_pooling2d_16[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 256, 256, 64  4160        ['conv2d_98[0][0]']
#                                 )
#
#  batch_normalization_76 (BatchN  (None, 256, 256, 64  256        ['conv2d_99[0][0]']
#  ormalization)                  )
#
#  activation_75 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_76[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 256, 256, 64  36928       ['activation_75[0][0]']
#                                 )
#
#  batch_normalization_77 (BatchN  (None, 256, 256, 64  256        ['conv2d_100[0][0]']
#  ormalization)                  )
#
#  global_average_pooling2d_18 (G  (None, 64)          0           ['batch_normalization_77[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_18 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_18[0][
#                                                                  0]']
#
#  dense_36 (Dense)               (None, 1, 1, 8)      520         ['reshape_18[0][0]']
#
#  dense_37 (Dense)               (None, 1, 1, 64)     576         ['dense_36[0][0]']
#
#  multiply_17 (Multiply)         (None, 256, 256, 64  0           ['batch_normalization_77[0][0]',
#                                 )                                 'dense_37[0][0]']
#
#  add_17 (Add)                   (None, 256, 256, 64  0           ['conv2d_98[0][0]',
#                                 )                                 'multiply_17[0][0]']
#
#  activation_76 (Activation)     (None, 256, 256, 64  0           ['add_17[0][0]']
#                                 )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 128, 128, 64  0          ['activation_76[0][0]']
#  )                              )
#
#  conv2d_101 (Conv2D)            (None, 128, 128, 12  8320        ['max_pooling2d_17[0][0]']
#                                 8)
#
#  conv2d_102 (Conv2D)            (None, 128, 128, 12  16512       ['conv2d_101[0][0]']
#                                 8)
#
#  batch_normalization_78 (BatchN  (None, 128, 128, 12  512        ['conv2d_102[0][0]']
#  ormalization)                  8)
#
#  activation_77 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_78[0][0]']
#                                 8)
#
#  conv2d_103 (Conv2D)            (None, 128, 128, 12  147584      ['activation_77[0][0]']
#                                 8)
#
#  batch_normalization_79 (BatchN  (None, 128, 128, 12  512        ['conv2d_103[0][0]']
#  ormalization)                  8)
#
#  global_average_pooling2d_19 (G  (None, 128)         0           ['batch_normalization_79[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_19 (Reshape)           (None, 1, 1, 128)    0           ['global_average_pooling2d_19[0][
#                                                                  0]']
#
#  dense_38 (Dense)               (None, 1, 1, 16)     2064        ['reshape_19[0][0]']
#
#  dense_39 (Dense)               (None, 1, 1, 128)    2176        ['dense_38[0][0]']
#
#  multiply_18 (Multiply)         (None, 128, 128, 12  0           ['batch_normalization_79[0][0]',
#                                 8)                                'dense_39[0][0]']
#
#  add_18 (Add)                   (None, 128, 128, 12  0           ['conv2d_101[0][0]',
#                                 8)                                'multiply_18[0][0]']
#
#  activation_78 (Activation)     (None, 128, 128, 12  0           ['add_18[0][0]']
#                                 8)
#
#  max_pooling2d_18 (MaxPooling2D  (None, 64, 64, 128)  0          ['activation_78[0][0]']
#  )
#
#  conv2d_104 (Conv2D)            (None, 64, 64, 256)  33024       ['max_pooling2d_18[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 64, 64, 256)  65792       ['conv2d_104[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_105[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_80[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_79[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_106[0][0]']
#  ormalization)
#
#  global_average_pooling2d_20 (G  (None, 256)         0           ['batch_normalization_81[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_20 (Reshape)           (None, 1, 1, 256)    0           ['global_average_pooling2d_20[0][
#                                                                  0]']
#
#  dense_40 (Dense)               (None, 1, 1, 32)     8224        ['reshape_20[0][0]']
#
#  dense_41 (Dense)               (None, 1, 1, 256)    8448        ['dense_40[0][0]']
#
#  multiply_19 (Multiply)         (None, 64, 64, 256)  0           ['batch_normalization_81[0][0]',
#                                                                   'dense_41[0][0]']
#
#  add_19 (Add)                   (None, 64, 64, 256)  0           ['conv2d_104[0][0]',
#                                                                   'multiply_19[0][0]']
#
#  activation_80 (Activation)     (None, 64, 64, 256)  0           ['add_19[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 32, 32, 256)  0          ['activation_80[0][0]']
#  )
#
#  conv2d_107 (Conv2D)            (None, 32, 32, 512)  1180160     ['max_pooling2d_19[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_107[0][0]']
#  ormalization)
#
#  activation_81 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_82[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 32, 32, 512)  2359808     ['activation_81[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_108[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_83[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 64, 64, 256)  524544     ['activation_82[0][0]']
#  nspose)
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_16[0][0]',
#                                                                   'activation_80[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 64, 64, 256)  1179904     ['concatenate_16[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_109[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_84[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_83[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_110[0][0]']
#  ormalization)
#
#  activation_84 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_85[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_84[0][0]']
#  nspose)                        8)
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_17[0][0]',
#                                 6)                                'activation_78[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 128, 128, 12  295040      ['concatenate_17[0][0]']
#                                 8)
#
#  batch_normalization_86 (BatchN  (None, 128, 128, 12  512        ['conv2d_111[0][0]']
#  ormalization)                  8)
#
#  activation_85 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_86[0][0]']
#                                 8)
#
#  conv2d_112 (Conv2D)            (None, 128, 128, 12  147584      ['activation_85[0][0]']
#                                 8)
#
#  batch_normalization_87 (BatchN  (None, 128, 128, 12  512        ['conv2d_112[0][0]']
#  ormalization)                  8)
#
#  activation_86 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_87[0][0]']
#                                 8)
#
#  conv2d_transpose_18 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_86[0][0]']
#  nspose)                        )
#
#  concatenate_18 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_18[0][0]',
#                                 8)                                'activation_76[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 256, 256, 64  73792       ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_88 (BatchN  (None, 256, 256, 64  256        ['conv2d_113[0][0]']
#  ormalization)                  )
#
#  activation_87 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_88[0][0]']
#                                 )
#
#  conv2d_114 (Conv2D)            (None, 256, 256, 64  36928       ['activation_87[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 256, 256, 64  256        ['conv2d_114[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_89[0][0]']
#                                 )
#
#  conv2d_transpose_19 (Conv2DTra  (None, 512, 512, 32  8224       ['activation_88[0][0]']
#  nspose)                        )
#
#  concatenate_19 (Concatenate)   (None, 512, 512, 64  0           ['conv2d_transpose_19[0][0]',
#                                 )                                 'activation_74[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 512, 512, 32  18464       ['concatenate_19[0][0]']
#                                 )
#
#  batch_normalization_90 (BatchN  (None, 512, 512, 32  128        ['conv2d_115[0][0]']
#  ormalization)                  )
#
#  activation_89 (Activation)     (None, 512, 512, 32  0           ['batch_normalization_90[0][0]']
#                                 )
#
#  conv2d_116 (Conv2D)            (None, 512, 512, 32  9248        ['activation_89[0][0]']
#                                 )
#
#  batch_normalization_91 (BatchN  (None, 512, 512, 32  128        ['conv2d_116[0][0]']
#  ormalization)                  )
#
#  activation_90 (Activation)     (None, 512, 512, 32  0           ['batch_normalization_91[0][0]']
#                                 )
#
#  conv2d_117 (Conv2D)            (None, 512, 512, 1)  33          ['activation_90[0][0]']
#
# ==================================================================================================
# Total params: 7,536,861
# Trainable params: 7,530,973
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
